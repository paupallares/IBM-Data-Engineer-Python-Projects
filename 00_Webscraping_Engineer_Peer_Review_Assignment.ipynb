# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork899-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Webscraping

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# - Use webscraping to get bank information

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
#!mamba install pandas==1.3.3 -y
#!mamba install requests==2.26.0 -y
#%pip install bs4 
# %pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /Users/ssanjua/Library/Python/3.11/lib/python/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from html5lib) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
from bs4 import BeautifulSoup
import html5lib
import requests
import pandas as pd

# %% [markdown]
# ## Extract Data Using Web Scraping

# %% [markdown]
# The wikipedia webpage https://web.archive.org/web/20200318083015/https://en.wikipedia.org/wiki/List_of_largest_banks provides information about largest banks in the world by various parameters. Scrape the data from the table 'By market capitalization' and store it in a JSON file.

# %% [markdown]
# ### Webpage Contents
#
# Gather the contents of the webpage in text format using the `requests` library and assign it to the variable <code>html_data</code>

# %%
#Write your code here

# URL of the webpage to scrape
url = "https://web.archive.org/web/20200318083015/https://en.wikipedia.org/wiki/List_of_largest_banks"

# Send a GET request to retrieve the webpage content
response = requests.get(url)


# Check if the request was successful
if response.status_code == 200:
    # Retrieve the HTML content
    html_data = response.text

    # Print the retrieved HTML content
    print(html_data)
else:
    print("Failed to retrieve the webpage.")
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head><script type="text/javascript" src="/_static/js/bundle-playback.js?v=1WaXNDFE" charset="utf-8"></script>
# <script type="text/javascript" src="/_static/js/wombat.js?v=txqj7nKC" charset="utf-8"></script>
# <script type="text/javascript">
#   __wm.init("https://web.archive.org/web");
#   __wm.wombat("https://en.wikipedia.org/wiki/List_of_largest_banks","20200318083015","https://web.archive.org/","web","/_static/",
# 	      "1584520215");
# </script>
# <link rel="stylesheet" type="text/css" href="/_static/css/banner-styles.css?v=S1zqJCYt" />
# <link rel="stylesheet" type="text/css" href="/_static/css/iconochive.css?v=qtvMKcIJ" />
# <!-- End Wayback Rewrite JS Include -->
#
# <meta charset="UTF-8"/>
# <title>List of largest banks - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XnEPUQpAIHkAArO0ZDcAAADR","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_largest_banks","wgTitle":"List of largest banks","wgCurRevisionId":946037317,"wgRevisionId":946037317,"wgArticleId":38298344,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Articles containing potentially dated statements from 2019","All articles containing potentially dated statements","Legal entities","Lists of banks",
# "Economy-related lists of superlatives"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_largest_banks","wgRelevantArticleId":38298344,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q3679682","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready",
# "user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","mediawiki.toc.styles":"ready","skins.vector.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","skins.vector.js","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks",
# "ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@tffin",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});</script>
# <link rel="stylesheet" href="/web/20200318083015cs_/https://en.wikipedia.org/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.toc.styles%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/web/20200318083015js_/https://en.wikipedia.org/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/web/20200318083015cs_/https://en.wikipedia.org/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.35.0-wmf.22"/>
# <meta name="referrer" content="origin"/>
# <meta name="referrer" content="origin-when-crossorigin"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/web/20200318083015/https://en.wikipedia.org/w/index.php?title=List_of_largest_banks&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=List_of_largest_banks&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/web/20200318083015im_/https://en.wikipedia.org/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/web/20200318083015im_/https://en.wikipedia.org/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/web/20200318083015/https://en.wikipedia.org/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="license" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="alternate" type="application/atom+xml" title="Wikipedia Atom feed" href="/web/20200318083015/https://en.wikipedia.org/w/index.php?title=Special:RecentChanges&amp;feed=atom"/>
# <link rel="canonical" href="https://web.archive.org/web/20200318083015/https://en.wikipedia.org/wiki/List_of_largest_banks"/>
# <link rel="dns-prefetch" href="//web.archive.org/web/20200318083015/https://login.wikimedia.org/"/>
# <link rel="dns-prefetch" href="//web.archive.org/web/20200318083015/https://meta.wikimedia.org/"/>
# <!--[if lt IE 9]><script src="/w/resources/lib/html5shiv/html5shiv.js"></script><![endif]-->
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_largest_banks rootpage-List_of_largest_banks skin-vector action-view">
# <div id="mw-page-base" class="noprint"></div>
# <div id="mw-head-base" class="noprint"></div>
# <div id="content" class="mw-body" role="main">
# 	<a id="top"></a>
# 	<div id="siteNotice" class="mw-body-content"><!-- CentralNotice --></div>
# 	<div class="mw-indicators mw-body-content">
# </div>
#
# 	<h1 id="firstHeading" class="firstHeading" lang="en">List of largest banks</h1>
#
# 	<div id="bodyContent" class="mw-body-content">
# 		<div id="siteSub" class="noprint">From Wikipedia, the free encyclopedia</div>
# 		<div id="contentSub"></div>
#
#
# 		<div id="jump-to-nav"></div>
# 		<a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# 		<a class="mw-jump-link" href="#p-search">Jump to search</a>
# 		<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><div class="mw-parser-output"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">Wikimedia list article</div>
# <p>These are lists of the <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Bank" title="Bank">banks</a> in the world, as measured by total <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Assets" class="mw-redirect" title="Assets">assets</a>.<sup id="cite_ref-SP_1-0" class="reference"><a href="#cite_note-SP-1">&#91;1&#93;</a></sup>
# </p>
# <div id="toc" class="toc" role="navigation" aria-labelledby="mw-toc-heading"><input type="checkbox" role="button" id="toctogglecheckbox" class="toctogglecheckbox" style="display:none"/><div class="toctitle" lang="en" dir="ltr"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#By_total_assets"><span class="tocnumber">1</span> <span class="toctext">By total assets</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Banks_by_country"><span class="tocnumber">1.1</span> <span class="toctext">Banks by country</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-3"><a href="#By_market_capitalization"><span class="tocnumber">2</span> <span class="toctext">By market capitalization</span></a>
# <ul>
# <li class="toclevel-2 tocsection-4"><a href="#Banks_by_country_2"><span class="tocnumber">2.1</span> <span class="toctext">Banks by country</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-5"><a href="#See_also"><span class="tocnumber">3</span> <span class="toctext">See also</span></a></li>
# <li class="toclevel-1 tocsection-6"><a href="#References"><span class="tocnumber">4</span> <span class="toctext">References</span></a></li>
# </ul>
# </div>
#
# <h2><span class="mw-headline" id="By_total_assets">By total assets</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/web/20200318083015/https://en.wikipedia.org/w/index.php?title=List_of_largest_banks&amp;action=edit&amp;section=1" title="Edit section: By total assets">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="thumb tright"><div class="thumbinner" style="width:222px;"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/File:ICBC_building_on_the_Bund,_Shanghai.jpg" class="image"><img alt="" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/5/5d/ICBC_building_on_the_Bund%2C_Shanghai.jpg/220px-ICBC_building_on_the_Bund%2C_Shanghai.jpg" decoding="async" width="220" height="135" class="thumbimage" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/5/5d/ICBC_building_on_the_Bund%2C_Shanghai.jpg/330px-ICBC_building_on_the_Bund%2C_Shanghai.jpg 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/5/5d/ICBC_building_on_the_Bund%2C_Shanghai.jpg/440px-ICBC_building_on_the_Bund%2C_Shanghai.jpg 2x" data-file-width="2452" data-file-height="1500"/></a>  <div class="thumbcaption"><div class="magnify"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/File:ICBC_building_on_the_Bund,_Shanghai.jpg" class="internal" title="Enlarge"></a></div>The <a href="/web/20200318083015/https://en.wikipedia.org/wiki/ICBC" class="mw-redirect" title="ICBC">ICBC</a> building on the Bund, Shanghai</div></div></div>
# <div class="thumb tright"><div class="thumbinner" style="width:152px;"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/File:China_merchants_bank_tower.jpg" class="image"><img alt="" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/6/68/China_merchants_bank_tower.jpg/150px-China_merchants_bank_tower.jpg" decoding="async" width="150" height="289" class="thumbimage" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/6/68/China_merchants_bank_tower.jpg/225px-China_merchants_bank_tower.jpg 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/6/68/China_merchants_bank_tower.jpg/300px-China_merchants_bank_tower.jpg 2x" data-file-width="846" data-file-height="1628"/></a>  <div class="thumbcaption"><div class="magnify"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/File:China_merchants_bank_tower.jpg" class="internal" title="Enlarge"></a></div>The <a href="/web/20200318083015/https://en.wikipedia.org/wiki/China_Merchants_Bank" title="China Merchants Bank">China Merchants Bank</a> in Shenzhen</div></div></div>
# <div class="thumb tright"><div class="thumbinner" style="width:202px;"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/File:Ping_An_Bank01.jpg" class="image"><img alt="" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Ping_An_Bank01.jpg/200px-Ping_An_Bank01.jpg" decoding="async" width="200" height="150" class="thumbimage" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Ping_An_Bank01.jpg/300px-Ping_An_Bank01.jpg 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Ping_An_Bank01.jpg/400px-Ping_An_Bank01.jpg 2x" data-file-width="2048" data-file-height="1536"/></a>  <div class="thumbcaption"><div class="magnify"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/File:Ping_An_Bank01.jpg" class="internal" title="Enlarge"></a></div>A <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Ping_An_Bank" title="Ping An Bank">Ping An Bank</a> branch</div></div></div>
# <p>The list is based on the 2019 <a href="/web/20200318083015/https://en.wikipedia.org/wiki/S%26P_Global_Market_Intelligence" class="mw-redirect" title="S&amp;P Global Market Intelligence">S&amp;P Global Market Intelligence</a> report of the 100 largest banks in the world.<sup id="cite_ref-SP_1-1" class="reference"><a href="#cite_note-SP-1">&#91;1&#93;</a></sup> The ranking was based upon assets as reported and was not adjusted for different accounting treatments.<sup id="cite_ref-SP_1-2" class="reference"><a href="#cite_note-SP-1">&#91;1&#93;</a></sup> Accounting treatment affects the assets reported: for example, the United States uses <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Generally_Accepted_Accounting_Principles_(United_States)" title="Generally Accepted Accounting Principles (United States)">US GAAP</a> (as opposed to <a href="/web/20200318083015/https://en.wikipedia.org/wiki/International_Financial_Reporting_Standards" title="International Financial Reporting Standards">IFRS</a>), which only reports the net <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Derivative_(finance)" title="Derivative (finance)">derivative</a> position in most cases, leading to US banks having fewer derivative assets than comparable non-US banks.<sup id="cite_ref-2" class="reference"><a href="#cite_note-2">&#91;2&#93;</a></sup> If <a href="/web/20200318083015/https://en.wikipedia.org/wiki/JPMorgan_Chase" title="JPMorgan Chase">JPMorgan Chase</a> reported under the IFRS, it would be ranked 4th in the list as of 2019<sup class="plainlinks noexcerpt noprint asof-tag update" style="display:none;"><a class="external text" href="https://web.archive.org/web/20200318083015/https://en.wikipedia.org/w/index.php?title=List_of_largest_banks&amp;action=edit">&#91;update&#93;</a></sup>, rather than 6th.<sup id="cite_ref-SP_1-3" class="reference"><a href="#cite_note-SP-1">&#91;1&#93;</a></sup>
# </p>
# <table class="wikitable sortable mw-collapsible">
#
# <tbody><tr>
# <th data-sort-type="number">Rank
# </th>
# <th>Bank name
# </th>
# <th>Total assets<br/>(<a href="/web/20200318083015/https://en.wikipedia.org/wiki/US$" class="mw-redirect" title="US$">US$</a> Billion)
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/China" title="China"><img alt="China" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Industrial_and_Commercial_Bank_of_China" title="Industrial and Commercial Bank of China">Industrial and Commercial Bank of China</a>
# </td>
# <td>4,027.44
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/China" title="China"><img alt="China" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/China_Construction_Bank" title="China Construction Bank">China Construction Bank</a>
# </td>
# <td>3,376.52
# </td></tr>
# <tr>
# <td>3
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/China" title="China"><img alt="China" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Agricultural_Bank_of_China" title="Agricultural Bank of China">Agricultural Bank of China</a>
# </td>
# <td>3,287.36
# </td></tr>
# <tr>
# <td>4
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/China" title="China"><img alt="China" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Bank_of_China" title="Bank of China">Bank of China</a>
# </td>
# <td>3,092.21
# </td></tr>
# <tr>
# <td>5
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Japan" title="Japan"><img alt="Japan" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/23px-Flag_of_Japan.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/35px-Flag_of_Japan.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/45px-Flag_of_Japan.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Mitsubishi_UFJ_Financial_Group" title="Mitsubishi UFJ Financial Group">Mitsubishi UFJ Financial Group</a>
# </td>
# <td>3,069.20
# </td></tr>
# <tr>
# <td>6
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/United_Kingdom" title="United Kingdom"><img alt="United Kingdom" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/35px-Flag_of_the_United_Kingdom.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/46px-Flag_of_the_United_Kingdom.svg.png 2x" data-file-width="1200" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/HSBC" title="HSBC">HSBC Holdings PLC</a>
# </td>
# <td>2,715.15
# </td></tr>
# <tr>
# <td>7
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/United_States" title="United States"><img alt="United States" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/JPMorgan_Chase" title="JPMorgan Chase">JPMorgan Chase</a>
# </td>
# <td>2,687.38
# </td></tr>
# <tr>
# <td>8
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/United_States" title="United States"><img alt="United States" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Bank_of_America" title="Bank of America">Bank of America</a>
# </td>
# <td>2,354.51
# </td></tr>
# <tr>
# <td>9
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/France" title="France"><img alt="France" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/23px-Flag_of_France.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/35px-Flag_of_France.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/45px-Flag_of_France.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/BNP_Paribas" title="BNP Paribas">BNP Paribas</a>
# </td>
# <td>2,336.66
# </td></tr>
# <tr>
# <td>10
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/France" title="France"><img alt="France" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/23px-Flag_of_France.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/35px-Flag_of_France.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/45px-Flag_of_France.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Cr%C3%A9dit_Agricole" title="Crédit Agricole">Crédit Agricole</a>
# </td>
# <td>2,123.61
# </td></tr>
# <tr>
# <td>11
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/United_States" title="United States"><img alt="United States" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Citigroup" title="Citigroup">Citigroup Inc.</a>
# </td>
# <td>1,917.38
# </td></tr>
# <tr>
# <td>12
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Japan" title="Japan"><img alt="Japan" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/23px-Flag_of_Japan.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/35px-Flag_of_Japan.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/45px-Flag_of_Japan.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Japan_Post_Bank" title="Japan Post Bank">Japan Post Bank</a>
# </td>
# <td>1,911.48
# </td></tr>
# <tr>
# <td>13
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/United_States" title="United States"><img alt="United States" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Wells_Fargo" title="Wells Fargo">Wells Fargo</a>
# </td>
# <td>1,895.88
# </td></tr>
# <tr>
# <td>14
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Japan" title="Japan"><img alt="Japan" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/23px-Flag_of_Japan.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/35px-Flag_of_Japan.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/45px-Flag_of_Japan.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Sumitomo_Mitsui_Financial_Group" title="Sumitomo Mitsui Financial Group">Sumitomo Mitsui Financial Group</a>
# </td>
# <td>1,848.20
# </td></tr>
# <tr>
# <td>15
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Japan" title="Japan"><img alt="Japan" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/23px-Flag_of_Japan.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/35px-Flag_of_Japan.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/45px-Flag_of_Japan.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Mizuho_Financial_Group" title="Mizuho Financial Group">Mizuho Financial Group</a>
# </td>
# <td>1,837.80
# </td></tr>
# <tr>
# <td>16
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Spain" title="Spain"><img alt="Spain" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/23px-Flag_of_Spain.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/35px-Flag_of_Spain.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/45px-Flag_of_Spain.svg.png 2x" data-file-width="750" data-file-height="500"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Banco_Santander" title="Banco Santander">Banco Santander</a>
# </td>
# <td>1,670.79
# </td></tr>
# <tr>
# <td>17
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Germany" title="Germany"><img alt="Germany" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/23px-Flag_of_Germany.svg.png" decoding="async" width="23" height="14" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/35px-Flag_of_Germany.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/46px-Flag_of_Germany.svg.png 2x" data-file-width="1000" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Deutsche_Bank" title="Deutsche Bank">Deutsche Bank</a>
# </td>
# <td>1,543.55
# </td></tr>
# <tr>
# <td>18
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/France" title="France"><img alt="France" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/23px-Flag_of_France.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/35px-Flag_of_France.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/45px-Flag_of_France.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Soci%C3%A9t%C3%A9_G%C3%A9n%C3%A9rale" title="Société Générale">Société Générale</a>
# </td>
# <td>1,485.31
# </td></tr>
# <tr>
# <td>19
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/France" title="France"><img alt="France" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/23px-Flag_of_France.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/35px-Flag_of_France.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/45px-Flag_of_France.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Groupe_BPCE" title="Groupe BPCE">Groupe BPCE</a>
# </td>
# <td>1,462.70
# </td></tr>
# <tr>
# <td>20
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/United_Kingdom" title="United Kingdom"><img alt="United Kingdom" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/35px-Flag_of_the_United_Kingdom.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/46px-Flag_of_the_United_Kingdom.svg.png 2x" data-file-width="1200" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Barclays" title="Barclays">Barclays</a>
# </td>
# <td>1,444.39
# </td></tr>
# <tr>
# <td>21
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/China" title="China"><img alt="China" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Bank_of_Communications" title="Bank of Communications">Bank of Communications</a>
# </td>
# <td>1,385.81
# </td></tr>
# <tr>
# <td>22
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/China" title="China"><img alt="China" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Postal_Savings_Bank_of_China" title="Postal Savings Bank of China">Postal Savings Bank of China</a>
# </td>
# <td>1,383.63
# </td></tr>
# <tr>
# <td>23
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Canada" title="Canada"><img alt="Canada" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Canada_%28Pantone%29.svg/23px-Flag_of_Canada_%28Pantone%29.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Canada_%28Pantone%29.svg/35px-Flag_of_Canada_%28Pantone%29.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Canada_%28Pantone%29.svg/46px-Flag_of_Canada_%28Pantone%29.svg.png 2x" data-file-width="1200" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Royal_Bank_of_Canada" title="Royal Bank of Canada">Royal Bank of Canada</a>
# </td>
# <td>1,039.24
# </td></tr>
# <tr>
# <td>24
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/United_Kingdom" title="United Kingdom"><img alt="United Kingdom" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/35px-Flag_of_the_United_Kingdom.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/46px-Flag_of_the_United_Kingdom.svg.png 2x" data-file-width="1200" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Lloyds_Banking_Group" title="Lloyds Banking Group">Lloyds Banking Group</a>
# </td>
# <td>1,016.55
# </td></tr>
# <tr>
# <td>25
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Netherlands" title="Netherlands"><img alt="Netherlands" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/23px-Flag_of_the_Netherlands.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/35px-Flag_of_the_Netherlands.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/45px-Flag_of_the_Netherlands.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/ING_Group" title="ING Group">ING Group</a>
# </td>
# <td>1,015.61
# </td></tr>
# <tr>
# <td>26
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Canada" title="Canada"><img alt="Canada" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Canada_%28Pantone%29.svg/23px-Flag_of_Canada_%28Pantone%29.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Canada_%28Pantone%29.svg/35px-Flag_of_Canada_%28Pantone%29.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Canada_%28Pantone%29.svg/46px-Flag_of_Canada_%28Pantone%29.svg.png 2x" data-file-width="1200" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Toronto-Dominion_Bank" title="Toronto-Dominion Bank">Toronto-Dominion Bank</a>
# </td>
# <td>1,006.00
# </td></tr>
# <tr>
# <td>27
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/China" title="China"><img alt="China" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/China_Merchants_Bank" title="China Merchants Bank">China Merchants Bank</a>
# </td>
# <td>980.81
# </td></tr>
# <tr>
# <td>28
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/France" title="France"><img alt="France" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/23px-Flag_of_France.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/35px-Flag_of_France.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/45px-Flag_of_France.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Cr%C3%A9dit_Mutuel" title="Crédit Mutuel">Crédit Mutuel</a>
# </td>
# <td>976.46
# </td></tr>
# <tr>
# <td>29
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Japan" title="Japan"><img alt="Japan" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/23px-Flag_of_Japan.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/35px-Flag_of_Japan.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/9/9e/Flag_of_Japan.svg/45px-Flag_of_Japan.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Norinchukin_Bank" title="Norinchukin Bank">Norinchukin Bank</a>
# </td>
# <td>961.37
# </td></tr>
# <tr>
# <td>30
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Switzerland" title="Switzerland"><img alt="Switzerland" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/16px-Flag_of_Switzerland.svg.png" decoding="async" width="16" height="16" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/24px-Flag_of_Switzerland.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/32px-Flag_of_Switzerland.svg.png 2x" data-file-width="512" data-file-height="512"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/UBS" title="UBS">UBS</a>
# </td>
# <td>958.49
# </td></tr>
# <tr>
# <td>31
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/China" title="China"><img alt="China" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Industrial_Bank_(China)" title="Industrial Bank (China)">Industrial Bank (China)</a>
# </td>
# <td>952.59
# </td></tr>
# <tr>
# <td>32
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Italy" title="Italy"><img alt="Italy" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/UniCredit" title="UniCredit">UniCredit</a>
# </td>
# <td>951.99
# </td></tr>
# <tr>
# <td>33
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/United_States" title="United States"><img alt="United States" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Goldman_Sachs" title="Goldman Sachs">Goldman Sachs</a>
# </td>
# <td>931.80
# </td></tr>
# <tr>
# <td>34
# </td>
# <td><span class="flagicon"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/China" title="China"><img alt="China" src="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/23px-Flag_of_the_People%27s_Republic_of_China.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/35px-Flag_of_the_People%27s_Republic_of_China.svg.png 1.5x, //web.archive.org/web/20200318083015im_/https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/45px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" data-file-width="900" data-file-height="600"/></a></span> <a href="/web/20200318083015/https://en.wikipedia.org/wiki/Shanghai_Pudong_Development_Bank" title="Shanghai Pudong Development Bank">Shanghai Pudong Development Bank</a>
# </td>
# <td>914.49
# </td></tr>
# <tr>
# <td>35
# </td>
# ...
# 	<h3>
# 		<label for="searchInput">Search</label>
# 	</h3>
# 	<form action="/web/20200318083015/https://en.wikipedia.org/w/index.php" id="searchform">
# 		<div id="simpleSearch">
# 			<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/>
# 			<input type="hidden" value="Special:Search" name="title"/>
# 			<input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/>
# 			<input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>
# 		</div>
# 	</form>
# </div>
#
#         </div>
#     </div>
#
# <div id="mw-panel">
# 	<div id="p-logo" role="banner">
# 		<a title="Visit the main page" class="mw-wiki-logo" href="/web/20200318083015/https://en.wikipedia.org/wiki/Main_Page"></a>
# 	</div>
# 	<div class="portal" role="navigation" id="p-navigation" aria-labelledby="p-navigation-label">
# 		<h3 id="p-navigation-label">
# 			Navigation
# 		</h3>
# 		<div class="body">
# 			<ul><li id="n-mainpage-description"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://web.archive.org/web/20200318083015/https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//web.archive.org/web/20200318083015/https://shop.wikimedia.org/" title="Visit the Wikipedia store">Wikipedia store</a></li></ul>
#
# 		</div>
# 	</div>
#
# 	<div class="portal" role="navigation" id="p-interaction" aria-labelledby="p-interaction-label">
# 		<h3 id="p-interaction-label">
# 			Interaction
# 		</h3>
# 		<div class="body">
# 			<ul><li id="n-help"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//web.archive.org/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li></ul>
#
# 		</div>
# 	</div>
#
# 	<div class="portal" role="navigation" id="p-tb" aria-labelledby="p-tb-label">
# 		<h3 id="p-tb-label">
# 			Tools
# 		</h3>
# 		<div class="body">
# 			<ul><li id="t-whatlinkshere"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Special:WhatLinksHere/List_of_largest_banks" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Special:RecentChangesLinked/List_of_largest_banks" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/web/20200318083015/https://en.wikipedia.org/w/index.php?title=List_of_largest_banks&amp;oldid=946037317" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/web/20200318083015/https://en.wikipedia.org/w/index.php?title=List_of_largest_banks&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://web.archive.org/web/20200318083015/https://www.wikidata.org/wiki/Special:EntityPage/Q3679682" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/web/20200318083015/https://en.wikipedia.org/w/index.php?title=Special:CiteThisPage&amp;page=List_of_largest_banks&amp;id=946037317" title="Information on how to cite this page">Cite this page</a></li></ul>
#
# 		</div>
# 	</div>
#
# 	<div class="portal" role="navigation" id="p-coll-print_export" aria-labelledby="p-coll-print_export-label">
# 		<h3 id="p-coll-print_export-label">
# 			Print/export
# 		</h3>
# 		<div class="body">
# 			<ul><li id="coll-create_a_book"><a href="/web/20200318083015/https://en.wikipedia.org/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=List+of+largest+banks">Create a book</a></li><li id="coll-download-as-rl"><a href="/web/20200318083015/https://en.wikipedia.org/w/index.php?title=Special:ElectronPdf&amp;page=List+of+largest+banks&amp;action=show-download-screen">Download as PDF</a></li><li id="t-print"><a href="/web/20200318083015/https://en.wikipedia.org/w/index.php?title=List_of_largest_banks&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li></ul>
#
# 		</div>
# 	</div>
#
# 	<div class="portal" role="navigation" id="p-lang" aria-labelledby="p-lang-label">
# 		<h3 id="p-lang-label">
# 			Languages
# 		</h3>
# 		<div class="body">
# 			<ul><li class="interlanguage-link interwiki-de"><a href="https://web.archive.org/web/20200318083015/https://de.wikipedia.org/wiki/Liste_der_gr%C3%B6%C3%9Ften_Banken_der_Welt" title="Liste der größten Banken der Welt – German" lang="de" hreflang="de" class="interlanguage-link-target">Deutsch</a></li><li class="interlanguage-link interwiki-fa"><a href="https://web.archive.org/web/20200318083015/https://fa.wikipedia.org/wiki/%D9%81%D9%87%D8%B1%D8%B3%D8%AA_%D8%A8%D8%B2%D8%B1%DA%AF%D8%AA%D8%B1%DB%8C%D9%86_%D8%A8%D8%A7%D9%86%DA%A9%E2%80%8C%D9%87%D8%A7" title="فهرست بزرگترین بانک‌ها – Persian" lang="fa" hreflang="fa" class="interlanguage-link-target">فارسی</a></li><li class="interlanguage-link interwiki-it"><a href="https://web.archive.org/web/20200318083015/https://it.wikipedia.org/wiki/Classifica_dei_gruppi_bancari_mondiali_con_maggiore_capitalizzazione" title="Classifica dei gruppi bancari mondiali con maggiore capitalizzazione – Italian" lang="it" hreflang="it" class="interlanguage-link-target">Italiano</a></li><li class="interlanguage-link interwiki-kk"><a href="https://web.archive.org/web/20200318083015/https://kk.wikipedia.org/wiki/%D0%86%D1%80%D1%96_%D0%B1%D0%B0%D0%BD%D0%BA%D1%82%D0%B5%D1%80_%D1%82%D1%96%D0%B7%D1%96%D0%BC%D1%96" title="Ірі банктер тізімі – Kazakh" lang="kk" hreflang="kk" class="interlanguage-link-target">Қазақша</a></li><li class="interlanguage-link interwiki-ro"><a href="https://web.archive.org/web/20200318083015/https://ro.wikipedia.org/wiki/List%C4%83_cu_cele_mai_importante_institu%C8%9Bii_de_credit" title="Listă cu cele mai importante instituții de credit – Romanian" lang="ro" hreflang="ro" class="interlanguage-link-target">Română</a></li><li class="interlanguage-link interwiki-uk"><a href="https://web.archive.org/web/20200318083015/https://uk.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BD%D0%B0%D0%B9%D0%B1%D1%96%D0%BB%D1%8C%D1%88%D0%B8%D1%85_%D0%B1%D0%B0%D0%BD%D0%BA%D1%96%D0%B2_%D1%81%D0%B2%D1%96%D1%82%D1%83" title="Список найбільших банків світу – Ukrainian" lang="uk" hreflang="uk" class="interlanguage-link-target">Українська</a></li><li class="interlanguage-link interwiki-vi"><a href="https://web.archive.org/web/20200318083015/https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_c%C3%A1c_ng%C3%A2n_h%C3%A0ng_l%E1%BB%9Bn_nh%E1%BA%A5t_th%E1%BA%BF_gi%E1%BB%9Bi" title="Danh sách các ngân hàng lớn nhất thế giới – Vietnamese" lang="vi" hreflang="vi" class="interlanguage-link-target">Tiếng Việt</a></li><li class="interlanguage-link interwiki-zh"><a href="https://web.archive.org/web/20200318083015/https://zh.wikipedia.org/wiki/%E4%B8%96%E7%95%8C%E6%9C%80%E5%A4%A7%E9%93%B6%E8%A1%8C%E5%88%97%E8%A1%A8" title="世界最大银行列表 – Chinese" lang="zh" hreflang="zh" class="interlanguage-link-target">中文</a></li></ul>
# 			<div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://web.archive.org/web/20200318083015/https://www.wikidata.org/wiki/Special:EntityPage/Q3679682#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>
# 		</div>
# 	</div>
#
# </div>
#
# </div>
#
#
# <div id="footer" role="contentinfo">
# 	<ul id="footer-info" class="">
# 		<li id="footer-info-lastmod"> This page was last edited on 17 March 2020, at 17:54<span class="anonymous-show">&#160;(UTC)</span>.</li>
# 		<li id="footer-info-copyright">Text is available under the <a rel="license" href="//web.archive.org/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//web.archive.org/web/20200318083015/https://creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//web.archive.org/web/20200318083015/https://foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//web.archive.org/web/20200318083015/https://foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//web.archive.org/web/20200318083015/https://www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 	</ul>
# 	<ul id="footer-places" class="">
# 		<li id="footer-places-privacy"><a href="https://web.archive.org/web/20200318083015/https://foundation.wikimedia.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 		<li id="footer-places-about"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 		<li id="footer-places-disclaimer"><a href="/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 		<li id="footer-places-contact"><a href="//web.archive.org/web/20200318083015/https://en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 		<li id="footer-places-developers"><a href="https://web.archive.org/web/20200318083015/https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 		<li id="footer-places-statslink"><a href="https://web.archive.org/web/20200318083015/https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# 		<li id="footer-places-cookiestatement"><a href="https://web.archive.org/web/20200318083015/https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# 		<li id="footer-places-mobileview"><a href="//web.archive.org/web/20200318083015/https://en.m.wikipedia.org/w/index.php?title=List_of_largest_banks&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 	</ul>
# 	<ul id="footer-icons" class="noprint">
# 		<li id="footer-copyrightico"><a href="https://web.archive.org/web/20200318083015/https://wikimediafoundation.org/"><img src="/web/20200318083015im_/https://en.wikipedia.org/static/images/wikimedia-button.png" srcset="/web/20200318083015im_/https://en.wikipedia.org/static/images/wikimedia-button-1.5x.png 1.5x, /web/20200318083015im_/https://en.wikipedia.org/static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a></li>
# 		<li id="footer-poweredbyico"><a href="https://web.archive.org/web/20200318083015/https://www.mediawiki.org/"><img src="/web/20200318083015im_/https://en.wikipedia.org/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/web/20200318083015im_/https://en.wikipedia.org/static/images/poweredby_mediawiki_132x47.png 1.5x, /web/20200318083015im_/https://en.wikipedia.org/static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a></li>
# 	</ul>
# 	<div style="clear: both;"></div>
# </div>
#
#
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.992","walltime":"1.157","ppvisitednodes":{"value":27683,"limit":1000000},"postexpandincludesize":{"value":143370,"limit":2097152},"templateargumentsize":{"value":39379,"limit":2097152},"expansiondepth":{"value":13,"limit":40},"expensivefunctioncount":{"value":2,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":10494,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  842.102      1 -total"," 65.57%  552.180    172 Template:Flagicon"," 11.48%   96.639      1 Template:Reflist"," 11.29%   95.092    172 Template:Flagicon/core"," 10.16%   85.570      3 Template:Cite_web","  7.76%   65.381      1 Template:Short_description","  7.56%   63.671    172 Template:Yesno-no","  5.94%   50.006      1 Template:Pagetype","  5.25%   44.204    172 Template:Yesno","  5.23%   44.000    174 Template:Main_other"]},"scribunto":{"limitreport-timeusage":{"value":"0.240","limit":"10.000"},"limitreport-memusage":{"value":2914430,"limit":52428800}},"cachereport":{"origin":"mw1324","timestamp":"20200317175458","ttl":2592000,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/web.archive.org\/web\/20200318083015\/https:\/\/schema.org","@type":"Article","name":"List of largest banks","url":"https:\/\/web.archive.org\/web\/20200318083015\/https:\/\/en.wikipedia.org\/wiki\/List_of_largest_banks","sameAs":"https:\/\/web.archive.org\/web\/20200318083015\/http:\/\/www.wikidata.org\/entity\/Q3679682","mainEntity":"https:\/\/web.archive.org\/web\/20200318083015\/http:\/\/www.wikidata.org\/entity\/Q3679682","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/web.archive.org\/web\/20200318083015\/https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2013-01-22T14:10:11Z","dateModified":"2020-03-17T17:54:54Z","headline":"Wikimedia list article"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":91,"wgHostname":"mw1405"});});</script></body></html>
# <!--
#      FILE ARCHIVED ON 08:30:15 Mar 18, 2020 AND RETRIEVED FROM THE
#      INTERNET ARCHIVE ON 01:36:10 Jul 10, 2023.
#      JAVASCRIPT APPENDED BY WAYBACK MACHINE, COPYRIGHT INTERNET ARCHIVE.
#
#      ALL OTHER CONTENT MAY ALSO BE PROTECTED BY COPYRIGHT (17 U.S.C.
#      SECTION 108(a)(3)).
# -->
# <!--
# playback timings (ms):
#   captures_list: 657.574
#   exclusion.robots: 0.14
#   exclusion.robots.policy: 0.129
#   cdx.remote: 0.06
#   esindex: 0.01
#   LoadShardBlock: 616.851 (3)
#   PetaboxLoader3.datanode: 71.624 (4)
#   load_resource: 151.638
#   PetaboxLoader3.resolve: 109.487
# -->

# %% [markdown]
# <b>Question 1</b> Print out the output of the following line, and remember it as it will be a quiz question:

# %%
html_data[760:783]
# Out:
# 'List of largest banks -'

# %% [markdown]
# ### Scraping the Data
#
# <b> Question 2</b> Using the contents and `beautiful soup` load the data from the `By market capitalization` table into a `pandas` dataframe. The dataframe should have the bank `Name` and `Market Cap (US$ Billion)` as column names.  Display the first five rows using head.

# %% [markdown]
# Using BeautifulSoup parse the contents of the webpage.

# %%
#Replace the dots below
soup= BeautifulSoup(html_data, "html.parser")

# %% [markdown]
# Load the data from the `By market capitalization` table into a pandas dataframe. The dataframe should have the bank `Name` and `Market Cap (US$ Billion)` as column names. Using the empty dataframe `data` and the given loop extract the necessary data from each row and append it to the empty dataframe.

# %%
data = pd.DataFrame(columns=["Name", "Market Cap (US$ Billion)"])

for row in soup.find_all('tbody')[2].find_all('tr'):
        col = row.find_all('td')
        if len(col) >= 2:
            bank_name = col[1].text.strip()
            market_cap = col[2].text.strip()
            data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# Out:
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)
# /var/folders/71/4rl6w509079c20dtbvnqwf1c0000gn/T/ipykernel_6462/4148953032.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"Name": bank_name, "Market Cap (US$ Billion)": market_cap}, ignore_index=True)

# %% [markdown]
# **Question 3** Display the first five rows using the `head` function.

# %%
#Write your code here
data.head()
# Out:
#                                       Name Market Cap (US$ Billion)
# 0                           JPMorgan Chase                  390.934
# 1  Industrial and Commercial Bank of China                  345.214
# 2                          Bank of America                  325.331
# 3                              Wells Fargo                  308.013
# 4                  China Construction Bank                  257.399

# %% [markdown]
# ### Loading the Data
#
# Load the `pandas` dataframe created above into a JSON named `bank_market_cap.json` using the `to_json()` function.

# %%
#Write your code here

# Convert the DataFrame to JSON
json_data = data.to_json(orient="records")

# Define the JSON file path
json_file = "bank_market_cap.json"

# Save the JSON data to the file
with open(json_file, "w") as file:
    file.write(json_data)

print("DataFrame successfully saved as JSON.")
# Out:
# DataFrame successfully saved as JSON.

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-07-12        | 0.2     | Appalabhaktula Hema | Corrected the code and markdown |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation.
